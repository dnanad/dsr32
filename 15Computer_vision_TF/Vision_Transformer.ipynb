# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import tensorflow_datasets as tfds
import numpy as np
import matplotlib.pyplot as plt

# %%
(dataset_train_original, dataset_validate_original, dataset_test_original), info = tfds.load(
    name="cats_vs_dogs", 
    split=["train[:70%]", "train[70%:90%]", "train[90%:]"],
    with_info=True,
    as_supervised=True
)
print(info)
# Out:
# Downloading and preparing dataset 786.68 MiB (download: 786.68 MiB, generated: Unknown size, total: 786.68 MiB) to ~/tensorflow_datasets/cats_vs_dogs/4.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling ~/tensorflow_datasets/cats_vs_dogs/4.0.0.incompleteO8Z13S/cats_vs_dogs-train.tfrecord*...:   0%|    …
# Dataset cats_vs_dogs downloaded and prepared to ~/tensorflow_datasets/cats_vs_dogs/4.0.0. Subsequent calls will reuse this data.
# tfds.core.DatasetInfo(
#     name='cats_vs_dogs',
#     full_name='cats_vs_dogs/4.0.0',
#     description="""
#     A large set of images of cats and dogs. There are 1738 corrupted images that are dropped.
#     """,
#     homepage='https://www.microsoft.com/en-us/download/details.aspx?id=54765',
#     data_path='~/tensorflow_datasets/cats_vs_dogs/4.0.0',
#     file_format=tfrecord,
#     download_size=786.67 MiB,
#     dataset_size=689.64 MiB,
#     features=FeaturesDict({
#         'image': Image(shape=(None, None, 3), dtype=tf.uint8),
#         'image/filename': Text(shape=(), dtype=tf.string),
#         'label': ClassLabel(shape=(), dtype=tf.int64, num_classes=2),
#     }),
#     supervised_keys=('image', 'label'),
#     disable_shuffling=False,
#     splits={
#         'train': <SplitInfo num_examples=23262, num_shards=8>,
#     },
#     citation="""@Inproceedings (Conference){asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization,
#     author = {Elson, Jeremy and Douceur, John (JD) and Howell, Jon and Saul, Jared},
#     title = {Asirra: A CAPTCHA that Exploits Interest-Aligned Manual Image Categorization},
#     booktitle = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     year = {2007},
#     month = {October},
#     publisher = {Association for Computing Machinery, Inc.},
#     url = {https://www.microsoft.com/en-us/research/publication/asirra-a-captcha-that-exploits-interest-aligned-manual-image-categorization/},
#     edition = {Proceedings of 14th ACM Conference on Computer and Communications Security (CCS)},
#     }""",
# )

# %%
image_size = 72
batch_size = 128

# %%
def encode(image, label):
    image_encoded = tf.image.convert_image_dtype(image, dtype=tf.float32)
    image_encoded = tf.image.resize(image_encoded, (image_size, image_size))
    return image_encoded, label

dataset = dataset_train_original.map(lambda image, label: encode(image, label))

index = 1
num_samples = 8
plt.figure(figsize=(24, 4))
for image, label in dataset.take(num_samples):
    plt.subplot(1, num_samples, index)
    plt.imshow(image)
    plt.title(f"Label: {label}\nShape: {image.shape}")
    plt.axis("off")
    index += 1

# %%
dataset_train = dataset_train_original.map(lambda image, label: encode(image, label)).cache().shuffle(25000).batch(batch_size)
dataset_validate = dataset_validate_original.map(lambda image, label: encode(image, label)).cache().batch(batch_size)
dataset_test = dataset_test_original.map(lambda image, label: encode(image, label)).cache().batch(batch_size)

# %%
history_list = {}
epochs = 25

def render_history(history):
    plt.plot(history["loss"], label="loss")
    plt.plot(history["val_loss"], label="val_loss")
    plt.legend()
    plt.title("Our losses")
    plt.show()
    plt.close()

    plt.plot(history["accuracy"], label="accuracy")
    plt.plot(history["val_accuracy"], label="val_accuracy")
    plt.legend()
    plt.title("Our accuracies")
    plt.show()
    plt.close()


def compare_histories():
    for training_name, history in history_list.items():
        plt.plot(history["val_accuracy"], label=training_name)
    plt.legend()
    plt.title("Comparison of val_accuracy")
    plt.show()
    plt.close()

# %%
model = models.Sequential()

model.add(layers.Input(shape=(image_size, image_size, 3)))
model.add(layers.Flatten())
model.add(layers.Dense(2048, activation="relu"))
model.add(layers.Dropout(0.0))
model.add(layers.Dense(1024, activation="relu"))
model.add(layers.Dropout(0.0))
model.add(layers.Dense(512, activation="relu"))
model.add(layers.Dropout(0.0))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.0))
model.add(layers.Dense(1, activation="sigmoid"))
model.summary()

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_validate
)

history_list["Dense"] = history.history
render_history(history.history)
compare_histories()
tf.keras.backend.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 15552)             0
#
#  dense (Dense)               (None, 2048)              31852544
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_3 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_4 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 34,607,105
# Trainable params: 34,607,105
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 128/128 [==============================] - 47s 94ms/step - loss: 1.1014 - accuracy: 0.5322 - val_loss: 0.7105 - val_accuracy: 0.5093
# Epoch 2/25
# 128/128 [==============================] - 3s 20ms/step - loss: 0.6704 - accuracy: 0.5879 - val_loss: 0.6681 - val_accuracy: 0.5844
# Epoch 3/25
# 128/128 [==============================] - 2s 19ms/step - loss: 0.6547 - accuracy: 0.6075 - val_loss: 0.8075 - val_accuracy: 0.5104
# Epoch 4/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6520 - accuracy: 0.6095 - val_loss: 0.6478 - val_accuracy: 0.6243
# Epoch 5/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6407 - accuracy: 0.6308 - val_loss: 0.6555 - val_accuracy: 0.6217
# Epoch 6/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6381 - accuracy: 0.6339 - val_loss: 0.6489 - val_accuracy: 0.6235
# Epoch 7/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6336 - accuracy: 0.6385 - val_loss: 0.6423 - val_accuracy: 0.6331
# Epoch 8/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6260 - accuracy: 0.6428 - val_loss: 0.6682 - val_accuracy: 0.6058
# Epoch 9/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6272 - accuracy: 0.6427 - val_loss: 0.6984 - val_accuracy: 0.5878
# Epoch 10/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6223 - accuracy: 0.6428 - val_loss: 0.6467 - val_accuracy: 0.6235
# Epoch 11/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6172 - accuracy: 0.6508 - val_loss: 0.6285 - val_accuracy: 0.6447
# Epoch 12/25
# 128/128 [==============================] - 2s 18ms/step - loss: 0.6137 - accuracy: 0.6566 - val_loss: 0.6436 - val_accuracy: 0.6250
# Epoch 13/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6079 - accuracy: 0.6657 - val_loss: 0.6343 - val_accuracy: 0.6426
# Epoch 14/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6039 - accuracy: 0.6678 - val_loss: 0.6264 - val_accuracy: 0.6475
# Epoch 15/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.6036 - accuracy: 0.6689 - val_loss: 0.6466 - val_accuracy: 0.6357
# Epoch 16/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5959 - accuracy: 0.6732 - val_loss: 0.7147 - val_accuracy: 0.6037
# Epoch 17/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5937 - accuracy: 0.6746 - val_loss: 0.6402 - val_accuracy: 0.6325
# Epoch 18/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5842 - accuracy: 0.6867 - val_loss: 0.6288 - val_accuracy: 0.6437
# Epoch 19/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5723 - accuracy: 0.6921 - val_loss: 0.6437 - val_accuracy: 0.6361
# Epoch 20/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5701 - accuracy: 0.6983 - val_loss: 0.6207 - val_accuracy: 0.6471
# Epoch 21/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5679 - accuracy: 0.6991 - val_loss: 0.6606 - val_accuracy: 0.6387
# Epoch 22/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5729 - accuracy: 0.6924 - val_loss: 0.6297 - val_accuracy: 0.6501
# Epoch 23/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5642 - accuracy: 0.7020 - val_loss: 0.6877 - val_accuracy: 0.6222
# Epoch 24/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5677 - accuracy: 0.6988 - val_loss: 0.6301 - val_accuracy: 0.6542
# Epoch 25/25
# 128/128 [==============================] - 2s 16ms/step - loss: 0.5586 - accuracy: 0.7073 - val_loss: 0.6342 - val_accuracy: 0.6471

# %%
model = models.Sequential()

model.add(layers.Input(shape=(image_size, image_size, 3)))
model.add(layers.Conv2D(32, 3, activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.1))
model.add(layers.Conv2D(32, 3, activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.2))
model.add(layers.Conv2D(64, 3, activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.3))
model.add(layers.Conv2D(128, 3, activation="relu"))
model.add(layers.MaxPooling2D(2))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dropout(0.5))
model.add(layers.Dense(1, activation="sigmoid"))
model.summary()

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_validate
)

history_list["CNN"] = history.history
render_history(history.history)
compare_histories()
tf.keras.backend.clear_session()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 70, 70, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 35, 35, 32)       0
#  )
#
#  dropout (Dropout)           (None, 35, 35, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 33, 33, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  dropout_2 (Dropout)         (None, 7, 7, 64)          0
#
#  conv2d_3 (Conv2D)           (None, 5, 5, 128)         73856
#
#  max_pooling2d_3 (MaxPooling  (None, 2, 2, 128)        0
#  2D)
#
#  dropout_3 (Dropout)         (None, 2, 2, 128)         0
#
#  flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 234,081
# Trainable params: 234,081
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 128/128 [==============================] - 11s 26ms/step - loss: 0.6920 - accuracy: 0.5225 - val_loss: 0.7071 - val_accuracy: 0.4960
# Epoch 2/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.6840 - accuracy: 0.5571 - val_loss: 0.6620 - val_accuracy: 0.5955
# Epoch 3/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.6285 - accuracy: 0.6440 - val_loss: 0.6045 - val_accuracy: 0.6720
# Epoch 4/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.5629 - accuracy: 0.7171 - val_loss: 0.5356 - val_accuracy: 0.7266
# Epoch 5/25
# 128/128 [==============================] - 3s 24ms/step - loss: 0.5242 - accuracy: 0.7466 - val_loss: 0.5241 - val_accuracy: 0.7533
# Epoch 6/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.4907 - accuracy: 0.7644 - val_loss: 0.5350 - val_accuracy: 0.7238
# Epoch 7/25
# 128/128 [==============================] - 3s 24ms/step - loss: 0.4641 - accuracy: 0.7832 - val_loss: 0.4805 - val_accuracy: 0.7606
# Epoch 8/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.4405 - accuracy: 0.7952 - val_loss: 0.4148 - val_accuracy: 0.8087
# Epoch 9/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.4257 - accuracy: 0.8014 - val_loss: 0.4010 - val_accuracy: 0.8201
# Epoch 10/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.4033 - accuracy: 0.8153 - val_loss: 0.3893 - val_accuracy: 0.8227
# Epoch 11/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3882 - accuracy: 0.8247 - val_loss: 0.4262 - val_accuracy: 0.8085
# Epoch 12/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3762 - accuracy: 0.8333 - val_loss: 0.4242 - val_accuracy: 0.7956
# Epoch 13/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3715 - accuracy: 0.8357 - val_loss: 0.3397 - val_accuracy: 0.8504
# Epoch 14/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.3482 - accuracy: 0.8479 - val_loss: 0.4123 - val_accuracy: 0.8074
# Epoch 15/25
# 128/128 [==============================] - 3s 26ms/step - loss: 0.3419 - accuracy: 0.8480 - val_loss: 0.3343 - val_accuracy: 0.8513
# Epoch 16/25
# 128/128 [==============================] - 4s 33ms/step - loss: 0.3314 - accuracy: 0.8545 - val_loss: 0.3570 - val_accuracy: 0.8354
# Epoch 17/25
# 128/128 [==============================] - 4s 31ms/step - loss: 0.3213 - accuracy: 0.8586 - val_loss: 0.3162 - val_accuracy: 0.8622
# Epoch 18/25
# 128/128 [==============================] - 4s 28ms/step - loss: 0.3111 - accuracy: 0.8630 - val_loss: 0.3105 - val_accuracy: 0.8674
# Epoch 19/25
# 128/128 [==============================] - 4s 29ms/step - loss: 0.3024 - accuracy: 0.8667 - val_loss: 0.3360 - val_accuracy: 0.8536
# Epoch 20/25
# 128/128 [==============================] - 4s 31ms/step - loss: 0.2971 - accuracy: 0.8732 - val_loss: 0.3277 - val_accuracy: 0.8567
# Epoch 21/25
# 128/128 [==============================] - 3s 25ms/step - loss: 0.3036 - accuracy: 0.8715 - val_loss: 0.3403 - val_accuracy: 0.8485
# Epoch 22/25
# 128/128 [==============================] - 4s 33ms/step - loss: 0.2875 - accuracy: 0.8758 - val_loss: 0.3267 - val_accuracy: 0.8496
# Epoch 23/25
# 128/128 [==============================] - 4s 28ms/step - loss: 0.2820 - accuracy: 0.8799 - val_loss: 0.3015 - val_accuracy: 0.8717
# Epoch 24/25
# 128/128 [==============================] - 3s 23ms/step - loss: 0.2732 - accuracy: 0.8816 - val_loss: 0.2971 - val_accuracy: 0.8693
# Epoch 25/25
# 128/128 [==============================] - 3s 26ms/step - loss: 0.2686 - accuracy: 0.8852 - val_loss: 0.2790 - val_accuracy: 0.8835

# %%
class Patches(layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="VALID",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
patch_size = 8

dataset = dataset_train_original.map(lambda image, label: encode(image, label)).shuffle(1000).batch(1)
patches_layer = Patches(patch_size=patch_size)

for image_batch, _ in dataset.take(1):
    print(image_batch.shape)

    # Render original image.
    plt.imshow(image_batch[0])
    plt.axis("off")
    plt.show()
    
    # Render patches.
    patches = patches_layer(image_batch)
    n = int(np.sqrt(patches.shape[1]))
    for i, patch in enumerate(patches[0]):
        ax = plt.subplot(n, n, i + 1)
        patch_img = tf.reshape(patch, (patch_size, patch_size, 3))
        plt.imshow(patch_img.numpy())
        plt.axis("off")
# Out:
# (1, 72, 72, 3)

# %%
class PatchEncoder(layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
patch_size = 8
num_patches = (image_size // patch_size) ** 2
embed_dim = 64 # Consider going down.

dataset = dataset_train_original.map(lambda image, label: encode(image, label)).shuffle(100).batch(1)
patches_layer = Patches(patch_size=patch_size)
patch_encoder_layer = PatchEncoder(num_patches=num_patches, projection_dim=embed_dim)

for image_batch, _ in dataset.take(1):
    
    # Render original image.
    plt.imshow(image_batch[0])
    plt.axis("off")
    plt.show()
    
    # Render encoded patches.
    patches = patches_layer(image_batch)
    patch_encoding = patch_encoder_layer(patches)
    plt.imshow(patch_encoding[0].numpy().transpose(), cmap="inferno")

# %%
class TransformerEncoder(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, dropout, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=dropout)
        self.dense_proj = tf.keras.Sequential(
            [
             layers.Dense(dense_dim, activation="relu"),
             layers.Dense(embed_dim),
             ]
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()

    def call(self, inputs):
        attention_output = self.attention(inputs, inputs)
        proj_input = self.layernorm_1(inputs + attention_output)
        proj_output = self.dense_proj(proj_input)
        return self.layernorm_2(proj_input + proj_output)

    def get_config(self):
        config = super().get_config()
        config.update({
            "embed_dim": self.embed_dim,
            "num_heads": self.num_heads,
            "dense_dim": self.dense_dim,
        })
        return config

# %%
patch_size = 8
num_patches = 81
num_heads = 2
num_encoders = 4
embed_dim = 64 # Consider going down.


model = models.Sequential()
model.add(layers.Input(shape=(image_size, image_size, 3)))
model.add(Patches(patch_size=patch_size))
model.add(PatchEncoder(num_patches=num_patches, projection_dim=embed_dim))
for _ in range(num_encoders):
    model.add(TransformerEncoder(embed_dim=embed_dim, dense_dim=embed_dim*2, num_heads=num_heads, dropout=0.0))
# model.add(layers.MaxPooling2D(2))
# model.add(layers.Dropout(0.1))
# model.add(layers.Conv2D(32, 3, activation="relu"))
# model.add(layers.MaxPooling2D(2))
# model.add(layers.Dropout(0.2))
# model.add(layers.Conv2D(64, 3, activation="relu"))
# model.add(layers.MaxPooling2D(2))
# model.add(layers.Dropout(0.3))
# model.add(layers.Conv2D(128, 3, activation="relu"))
# model.add(layers.MaxPooling2D(2))
# model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
# model.add(layers.Dense(256, activation="relu"))
# model.add(layers.Dropout(0.5))
model.add(layers.Dense(256, activation="relu"))
model.add(layers.Dense(1, activation="sigmoid"))

model.summary()

model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

history = model.fit(
    dataset_train,
    epochs=epochs,
    validation_data=dataset_validate
)

history_list["ViT"] = history.history
render_history(history.history)
compare_histories()
tf.keras.backend.clear_session()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  patches_12 (Patches)        (None, None, 192)         0
#
#  patch_encoder_7 (PatchEncod  (None, 81, 64)           17536
#  er)
#
#  transformer_encoder_4 (Tran  (None, 81, 64)           50048
#  sformerEncoder)
#
#  transformer_encoder_5 (Tran  (None, 81, 64)           50048
#  sformerEncoder)
#
#  transformer_encoder_6 (Tran  (None, 81, 64)           50048
#  sformerEncoder)
#
#  transformer_encoder_7 (Tran  (None, 81, 64)           50048
#  sformerEncoder)
#
#  flatten (Flatten)           (None, 5184)              0
#
#  dense_24 (Dense)            (None, 256)               1327360
#
#  dense_25 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 1,545,345
# Trainable params: 1,545,345
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/25
# 128/128 [==============================] - 9s 45ms/step - loss: 0.9507 - accuracy: 0.4979 - val_loss: 0.6870 - val_accuracy: 0.5682
# Epoch 2/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.6896 - accuracy: 0.5624 - val_loss: 0.6530 - val_accuracy: 0.6220
# Epoch 3/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.6286 - accuracy: 0.6471 - val_loss: 0.6759 - val_accuracy: 0.6276
# Epoch 4/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.5759 - accuracy: 0.6977 - val_loss: 0.6536 - val_accuracy: 0.6604
# Epoch 5/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.5393 - accuracy: 0.7249 - val_loss: 0.5479 - val_accuracy: 0.7217
# Epoch 6/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.4966 - accuracy: 0.7555 - val_loss: 0.5477 - val_accuracy: 0.7202
# Epoch 7/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.4685 - accuracy: 0.7782 - val_loss: 0.5520 - val_accuracy: 0.7264
# Epoch 8/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.4410 - accuracy: 0.7916 - val_loss: 0.5325 - val_accuracy: 0.7309
# Epoch 9/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.4137 - accuracy: 0.8092 - val_loss: 0.5397 - val_accuracy: 0.7341
# Epoch 10/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.3762 - accuracy: 0.8293 - val_loss: 0.5698 - val_accuracy: 0.7320
# Epoch 11/25
# 128/128 [==============================] - 6s 49ms/step - loss: 0.3407 - accuracy: 0.8486 - val_loss: 0.5722 - val_accuracy: 0.7374
# Epoch 12/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.2914 - accuracy: 0.8739 - val_loss: 0.6292 - val_accuracy: 0.7408
# Epoch 13/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.2394 - accuracy: 0.9001 - val_loss: 0.6132 - val_accuracy: 0.7423
# Epoch 14/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.1986 - accuracy: 0.9200 - val_loss: 0.6585 - val_accuracy: 0.7361
# Epoch 15/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.1587 - accuracy: 0.9370 - val_loss: 0.7026 - val_accuracy: 0.7359
# Epoch 16/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.1173 - accuracy: 0.9566 - val_loss: 0.8290 - val_accuracy: 0.7436
# Epoch 17/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0982 - accuracy: 0.9638 - val_loss: 0.8826 - val_accuracy: 0.7408
# Epoch 18/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0666 - accuracy: 0.9762 - val_loss: 0.9221 - val_accuracy: 0.7337
# Epoch 19/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0484 - accuracy: 0.9840 - val_loss: 0.9071 - val_accuracy: 0.7408
# Epoch 20/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0557 - accuracy: 0.9818 - val_loss: 0.9816 - val_accuracy: 0.7419
# Epoch 21/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0414 - accuracy: 0.9861 - val_loss: 0.9759 - val_accuracy: 0.7378
# Epoch 22/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0383 - accuracy: 0.9867 - val_loss: 1.1748 - val_accuracy: 0.7357
# Epoch 23/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0288 - accuracy: 0.9899 - val_loss: 1.1296 - val_accuracy: 0.7378
# Epoch 24/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0412 - accuracy: 0.9853 - val_loss: 1.1454 - val_accuracy: 0.7311
# Epoch 25/25
# 128/128 [==============================] - 5s 39ms/step - loss: 0.0612 - accuracy: 0.9761 - val_loss: 1.0275 - val_accuracy: 0.7479
