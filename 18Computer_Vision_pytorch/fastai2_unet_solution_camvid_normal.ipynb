# %%
## installs fastai v2 (Google Colab comes with fastai v1 by default)
# this will also ask permision to access your Google Drive
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
#      |████████████████████████████████| 719 kB 4.0 MB/s
#      |████████████████████████████████| 365 kB 51.3 MB/s
#      |████████████████████████████████| 4.7 MB 53.4 MB/s
#      |████████████████████████████████| 1.3 MB 20.3 MB/s
#      |████████████████████████████████| 120 kB 41.0 MB/s
#      |████████████████████████████████| 212 kB 52.2 MB/s
#      |████████████████████████████████| 115 kB 37.7 MB/s
#      |████████████████████████████████| 127 kB 43.3 MB/s
#      |████████████████████████████████| 6.6 MB 36.6 MB/s
# Mounted at /content/gdrive

# %%
# the variable gdrive now contains you Google Drive path
# this is a pathlib Path object
# we can create new file paths from it using the '/' operator
# See: https://realpython.com/python-pathlib/
from fastbook import *
gdrive
# Out:
# Path('/content/gdrive/My Drive')

# %%
# See: https://www.geeksforgeeks.org/python-os-path-exists-method/
if not (gdrive / 'camvid_normal').is_dir():
  # https://www.geeksforgeeks.org/python-os-mkdir-method/
  os.mkdir(gdrive / 'camvid_normal')

# %%
# evaluate this only once
# untar_data will download the folder and decompress it  
# path = untar_data(URLs.CAMVID, data = gdrive / 'camvid_normal')

# %%
import os
path = gdrive / 'camvid_normal' / 'camvid'
os.listdir(path)
# Out:
# ['labels', 'codes.txt', 'valid.txt', 'images', 'models', 'trained_unet.pkl']

# %%
# codes.txt contains the label code for our pixels 
# class 0 is Animal, class 1 is Archway
# class 2 is Bicyclist, etc. 
codes = np.loadtxt(path/'codes.txt', dtype=str)
codes
# Out:
# array(['Animal', 'Archway', 'Bicyclist', 'Bridge', 'Building', 'Car', 'CartLuggagePram', 'Child', 'Column_Pole', 'Fence', 'LaneMkgsDriv', 'LaneMkgsNonDriv', 'Misc_Text', 'MotorcycleScooter',
#        'OtherMoving', 'ParkingBlock', 'Pedestrian', 'Road', 'RoadShoulder', 'Sidewalk', 'SignSymbol', 'Sky', 'SUVPickupTruck', 'TrafficCone', 'TrafficLight', 'Train', 'Tree', 'Truck_Bus', 'Tunnel',
#        'VegetationMisc', 'Void', 'Wall'], dtype='<U17')

# %%
from PIL import Image
unlabeled_images = os.listdir(path / 'images')
print(path / 'images' / unlabeled_images[0])
image = Image.open(path / 'images' / unlabeled_images[0])
image
# Out:
# /content/gdrive/My Drive/camvid_normal/camvid/images/0006R0_f01320.png
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=960x720>

# %%
import matplotlib.pyplot as plt
# let's see its dimensions 
pix = np.array(image)
print(pix.shape)
plt.imshow(pix);
# Out:
# (720, 960, 3)

# %%
# check out what Path.stem and Path.suffix give us
Path(unlabeled_images[0]).stem, Path(unlabeled_images[0]).suffix
# Out:
# ('0006R0_f01320', '.png')

# %%
# in the labels folder we have a 0016E5_08370_P.png file with a label for every pixel in the image
label_file_path = f'{Path(unlabeled_images[0]).stem}_P{Path(unlabeled_images[0]).suffix}' 
label_file_path
# Out:
# '0006R0_f01320_P.png'

# %%
# it's a gray scale image
label = Image.open(path / 'labels' / label_file_path)
label
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=960x720>

# %%
# matplotlib allows to view it with a colormap
import numpy as np
label_array = np.array(label)
print(label_array.min(), label_array.max())
plt.imshow(label_array, cmap='Set3');
# Out:
# 3 31

# %%
# get the path of the matching image
# getting the label names for all files
label_names = [path/'labels'/f'{Path(o).stem}_P{Path(o).suffix}'  for o in unlabeled_images]
label_names[0:10]
# Out:
# [Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0006R0_f01320_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0006R0_f03750_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0016E5_01470_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0001TP_006810_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0001TP_009630_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0006R0_f03600_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0006R0_f03240_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0006R0_f01410_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0006R0_f02940_P.png'),
#  Path('/content/gdrive/My Drive/camvid_normal/camvid/labels/0006R0_f02220_P.png')]

# %%
# turn it into a labeling function
def label_func(x): 
  return path/'labels'/f'{x.stem}_P{x.suffix}'

# %%
# https://docs.fast.ai/vision.data.html#SegmentationDataLoaders
set_seed(42)
dls = SegmentationDataLoaders.from_label_func(
    path, 
    # note that I use a smaller batch size when dealing with bigger images
    bs=2, 
    fnames = get_image_files(path/"images"),
    label_func = label_func,
    codes = np.loadtxt(path/'codes.txt', dtype=str)
)

# %%
# show a batch of data, the masks will be overlayed on the images
dls.show_batch()

# %%
# we get a batch of data as training tensor images and training tensor labels using one_batch()
x, y = dls.one_batch()
# the labels are now images with the same dimensions as the input 
# labels are encoded as integers 
x.shape, y.shape
# Out:
# (torch.Size([2, 3, 720, 960]), torch.Size([2, 720, 960]))

# %%
# we create a unet_learner with a resnet18 backbone

learn = unet_learner(dls, resnet18, pretrained=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
# find a "good" learning rate
lrs = learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# fine tune for only two epochs
learn.fine_tune(2, base_lr=lrs.valley)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.102330</td>
#       <td>0.874178</td>
#       <td>04:21</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.731555</td>
#       <td>0.721841</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.632623</td>
#       <td>0.653632</td>
#       <td>04:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
# see results 
learn.show_results(max_n=3, figsize=(10, 10))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# train for six more epochs
learn.fine_tune(6, base_lr=lrs.valley)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.644828</td>
#       <td>0.615125</td>
#       <td>04:20</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.560942</td>
#       <td>0.582531</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.521089</td>
#       <td>0.540719</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.527369</td>
#       <td>0.511160</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.455587</td>
#       <td>0.486065</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.429086</td>
#       <td>0.479654</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.408263</td>
#       <td>0.474871</td>
#       <td>04:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
# see results again
learn.show_results(max_n=3, figsize=(10, 10))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
# train for 10 more epochs, use default learning rate
learn.fine_tune(10)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.191103</td>
#       <td>1.096652</td>
#       <td>04:20</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.529092</td>
#       <td>0.548207</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.500510</td>
#       <td>0.552497</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.454935</td>
#       <td>0.479419</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.387378</td>
#       <td>0.410597</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.327264</td>
#       <td>0.402474</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.264598</td>
#       <td>0.367960</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.220357</td>
#       <td>0.330854</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.197455</td>
#       <td>0.312793</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.169738</td>
#       <td>0.294617</td>
#       <td>04:27</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.169387</td>
#       <td>0.301052</td>
#       <td>04:27</td>
#     </tr>
#   </tbody>
# </table>

# %%
# results will be ok for many applications (e.g. road or sky segmentation)
# but not particularly impressive for small blobs/objects 
# don't use this to detect cars/pedestrians!  
learn.show_results(max_n=3, figsize=(10, 10))
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
learn.export(path / 'trained_unet.pkl')
